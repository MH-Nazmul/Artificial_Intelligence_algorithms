# %%
import numpy as np 
import pandas as pd
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
X = data.data
y = data.target

# %%
from sklearn.preprocessing import StandardScaler
import tensorflow 
from tensorflow import keras
from keras.utils import to_categorical

# %%
y_cat = to_categorical(y)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_cat, test_size=0.2, random_state = 42)

# %%
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(16, activation = 'relu', input_shape = (4,)))
model.add(Dense(8, activation ='relu'))
model.add(Dense(3, activation = 'softmax'))
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam', loss = "categorical_crossentropy", metrics = ['accuracy'])

# %%
history = model.fit(X_train_sc, y_train,epochs = 50, batch_size=8, verbose = 1)
# Out:
# Epoch 1/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.5529 - loss: 1.0268
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.6379 - loss: 0.9305
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - accuracy: 0.6086 - loss: 0.8433
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.6655 - loss: 0.7571
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.6934 - loss: 0.6602
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 0.6765 - loss: 0.6503
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7387 - loss: 0.6096
# Epoch 8/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.7532 - loss: 0.5586
# Epoch 9/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.8566 - loss: 0.5091
# Epoch 10/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.8606 - loss: 0.4723
# Epoch 11/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - accuracy: 0.8532 - loss: 0.4241
# Epoch 12/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.8717 - loss: 0.4237
# Epoch 13/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 0.8789 - loss: 0.4291
# Epoch 14/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.8513 - loss: 0.4113
# Epoch 15/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8691 - loss: 0.4169
# Epoch 16/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.8671 - loss: 0.3636
# Epoch 17/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.8818 - loss: 0.3573
# Epoch 18/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - accuracy: 0.8339 - loss: 0.3750
# Epoch 19/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.8486 - loss: 0.3684
# Epoch 20/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step - accuracy: 0.9138 - loss: 0.3160
# Epoch 21/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.8607 - loss: 0.3229
# Epoch 22/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.8861 - loss: 0.3019
# Epoch 23/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.8340 - loss: 0.3244
# Epoch 24/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.8594 - loss: 0.2991
# Epoch 25/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.8828 - loss: 0.2761
# Epoch 26/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 829us/step - accuracy: 0.8688 - loss: 0.2776
# Epoch 27/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - accuracy: 0.8933 - loss: 0.2592
# Epoch 28/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 0.8771 - loss: 0.3052
# Epoch 29/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.9219 - loss: 0.2299
# Epoch 30/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.9111 - loss: 0.2517
# Epoch 31/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.9153 - loss: 0.2352
# Epoch 32/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.9271 - loss: 0.2021
# Epoch 33/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.9357 - loss: 0.1876
# Epoch 34/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.9279 - loss: 0.2115
# Epoch 35/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.9114 - loss: 0.2016
# Epoch 36/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 827us/step - accuracy: 0.9377 - loss: 0.1702
# Epoch 37/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.9115 - loss: 0.2040
# Epoch 38/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 819us/step - accuracy: 0.9180 - loss: 0.1745
# Epoch 39/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.9262 - loss: 0.1861
# Epoch 40/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 0.9304 - loss: 0.1878
# Epoch 41/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.9551 - loss: 0.1222
# Epoch 42/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.9763 - loss: 0.1202
# Epoch 43/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.9658 - loss: 0.1512
# Epoch 44/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 818us/step - accuracy: 0.9595 - loss: 0.1180
# Epoch 45/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.9260 - loss: 0.1523
# Epoch 46/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.9355 - loss: 0.1527
# Epoch 47/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - accuracy: 0.9539 - loss: 0.1187
# Epoch 48/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.9668 - loss: 0.1047
# Epoch 49/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 826us/step - accuracy: 0.9282 - loss: 0.1430
# Epoch 50/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 832us/step - accuracy: 0.9448 - loss: 0.1119

# %%
pred = model.predict(X_test_sc)

pred_labels = np.argmax(pred, axis = 1)
true_labels = np.argmax(y_test, axis = 1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(true_labels,pred_labels)


acc
# Out:
# 1.0

# %%
pred_labels
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
true_labels
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
X_test_sc.shape
# Out:
# (30, 4)

# %%
# # X_test এর 5 নম্বর data point
# sample = X_test[27]

# # Scale করতে হবে (কারণ model scaled ডেটা দিয়ে train হয়েছিল)
# sample_sc = sc.transform(sample.reshape(1, -1))

# # Predict
# sample_pred = model.predict(sample_sc)

# # Probability → class label
# sample_label = np.argmax(sample_pred, axis=1)

# sample, sample_label

# %%
sample = X_test[[26]]

sample_sc = sc.transform(sample)

sample_pred = model.predict(sample_sc)

sample_label = np.argmax(sample_pred, axis = 1)

sample, sample_pred, sample_label
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# (array([[6.7, 2.5, 5.8, 1.8]]),
#  array([[3.5649369e-05, 4.5264173e-02, 9.5470023e-01]], dtype=float32),
#  array([2]))
